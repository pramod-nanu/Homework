# %% [markdown]
# <a href="https://colab.research.google.com/github/pramod-nanu/Homework/blob/main/Homework_10thNov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1.Write a program to find biggest of given 3 number from cmd prompt

# %%
a = int(input("Enter first number "))
b = int(input("Enter Second number "))
c = int(input("Enter third number "))
print("Greatest number is",max(a,b,c))
# Out:
# Enter first number 45
# Enter Second number 6812
# Enter third number 21
# Greatest number is 6812

# %% [markdown]
# ### 2.Write a prgram to find smallest of given two numbers

# %%
a = 10
b = 30
if a>b:
  print("Smallest number is :",b)
else:
  print("Smallest number is :",a)
# Out:
# Smallest number is : 10

# %% [markdown]
# ### 3.Write a prgram to find smallest of given two numbers

# %%
a = 100
b = 20
c = 60
print("Smallest number is ",min(a,b,c))
# Out:
# Smallest number is  20

# %% [markdown]
# ### 4.Write a program to find number is even or odd

# %%
num = int(input("Enter any number"))
print("You entered this number ",num)
if(num % 2 == 0):
  print("Given num is Even")
else:
  print("Given num is Odd")
# Out:
# Enter any number345
# You entered this number  345
# Given num is Odd

# %% [markdown]
# ### 5. Find Factorial number using For loop

# %%
import math

num = int(input("Enter any number "))
i = 1
res = 1
for i in range(1,num+1):
  res = res * i
print("Factorial of enetered number is ",res)

print("Now Using Factorial function")
print(math.factorial(num))

# %% [markdown]
# ### Find Factorian using while loop

# %%
num = int(input("Enter any number : "))
i=1
res= 1
while(i<=num):
  res = res * i
  i = i+1
print(res)
# Out:
# Enter any number : 6
# 720
